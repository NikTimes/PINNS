# %%
import sys
sys.path.insert(0, "..")

from src.models        import DeepONet, build_deeponet
from src.data          import ODEIterableDataset, LatinHypercubeSampler
from src.physics       import harm_osc, ODEsolver

import numpy as np
import matplotlib.pyplot as plt 
import torch
from torch.utils.data import DataLoader

device        = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Initialize Harmonic Oscillator Object 
k = 2.0
c = 0.1
system = harm_osc([k, c])
solver = ODEsolver(system).solve

# Initialize Sampler Object 
sampler = LatinHypercubeSampler(

    dimensions = 2,
    lows       = [-1.0, -1.0],
    highs      = [1.0, 1.0]
    
)

# %%
dataset_size = 1001
batch_size   = 1
num_workers  = 2
t_final      = 10
t_span       = (0, t_final)

osc_dataset = ODEIterableDataset(size          = dataset_size,
                                 system_class  = system,
                                 sampler       = sampler,
                                 t_span        = t_span,
                                 full_solution = True)

osc_loader  = DataLoader(dataset     = osc_dataset,
                         batch_size  = batch_size,
                         num_workers = num_workers)

# %%
# Set Up DeepONet configuration 

DEEPONET_CONFIG = {
    
    "hidden_size" : 32,
    "depth"       : 4,
    "latent_size" : 50,
    "input_size_b": 2,
    "input_size_t": 1,
    "output_size" : 1,
    "activation"  : "tanh",

}

# 1. Initialize DeepONet network 

deeponet = build_deeponet(DEEPONET_CONFIG)

# 2. Load the saved weights into the model

state_dict = torch.load("../weights/best_1d_osc.pth", map_location=device)
deeponet.load_state_dict(state_dict)
deeponet = deeponet.to(device)

# 3. Set to eval mode
deeponet.eval()
_ = 0

# %%
from src.benchmark import trajectory 

t, sol, pred = trajectory(deeponet, osc_loader, device)

# %%
# Plotting 

plt.figure(figsize=(12, 5))
plt.plot(t, sol[0], color="steelblue", lw=2, label="Ground Truth")
plt.plot(t, pred, color="tomato",    lw=2, label="DeepONet", linestyle="--")
plt.title("Damped Harmonic Oscillator: Ground Truth vs DeepONet", fontsize=14, fontweight="bold")
plt.ylabel("Position $x(t)$", fontsize=12)
plt.xlabel("Time $t$ (s)", fontsize=12)
plt.legend(fontsize=11, framealpha=0.9)
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
from src.benchmark import timing_data

num_boxes   = 10
num_samples = 1000

nn_timing, solver_timing = timing_data(model       = deeponet, 
                                        ODEsolver   = solver, 
                                        sampler     = sampler,
                                        t_final     = t_final, 
                                        num_samples = num_samples,
                                        num_boxes   = num_boxes, 
                                        device      = device)

# %%
# --- Timing boxplots ---
plt.figure(figsize=(10, 5))

plt.boxplot(solver_timing, 
            positions=np.arange(num_boxes) - 0.1,
            widths=0.5, 
            patch_artist=True)
                  
plt.boxplot(nn_timing, 
            positions=np.arange(num_boxes) + 0.1,
            widths=0.5, 
            patch_artist=True)

plt.xticks(np.arange(num_boxes))
plt.xlabel("Time Point")
plt.ylabel("Time (s)")

plt.title("Timing & Accuracy Comparison")
plt.tight_layout()
plt.show()

# %%
from src.benchmark import semigroup_data

loss_fn = torch.nn.MSELoss()

loss_direct, loss_2step, loss_3step = semigroup_data(model     = deeponet,
                                                     ODEsolver = solver, 
                                                     sampler   = sampler, 
                                                     loss_fn   = loss_fn,
                                                     t_final   = t_final,
                                                     num_samples = num_samples,
                                                     num_boxes   = num_boxes,
                                                     out_mask    = np.array([0]),
                                                     device      = device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 5
#       1 from src.benchmark import semigroup_data
#       3 loss_fn = torch.nn.MSELoss()
# ----> 5 loss_direct, loss_2step, loss_3step = semigroup_data(model     = deeponet,
#       6                                                      ODEsolver = solver,
#       7                                                      sampler   = sampler,
#       8                                                      loss_fn   = loss_fn,
#       9                                                      t_final   = t_final,
#      10                                                      num_samples = num_samples,
#      11                                                      num_boxes   = num_boxes,
#      12                                                      out_mask    = np.array([0]),
#      13                                                      device      = device)
#
# File ~/repos/PINNS/notebooks/../src/benchmark/semigroup.py:51, in semigroup_data(model, ODEsolver, sampler, loss_fn, t_final, num_samples, num_boxes, out_mask, device)
#      49 t_half   = torch.tensor([[t_val / 2]], dtype=torch.float32).to(device)
#      50 p2       = model(y0_tensor, t_half)
# ---> 51 p2       = model(p2, t_half)
#      53 # Solve using three timesteps
#      54 t_third  = torch.tensor([[t_val / 3]], dtype=torch.float32).to(device)
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/repos/PINNS/notebooks/../src/models/deeponet.py:26, in DeepONet.forward(self, u, y)
#      23 def forward(self, u, y):
#      24
#      25     # Shape (B, p)
# ---> 26     b = self.branch_net(u)
#      27     t = self.trunk_net(y, final_activation=True)
#      29     # Check that b, and t latent spaces can be divided in chunks
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/repos/PINNS/notebooks/../src/models/mlp.py:67, in General_MLP.forward(self, x, final_activation)
#      53 """
#      54 This method sequentially feeds the data through tall layers of the MLP.
#      55 It is also necessary for training the neural network
#    (...)     62     tensor : MLP output
#      63 """
#      65 for i in range(self.depth - 1):
# ---> 67     x = self.layers[i](x)
#      68     x = self.act(x)
#      70 x = self.layers[-1](x)
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x1 and 2x32)

# %%
# --- Timing boxplots ---
plt.figure(figsize=(10, 5))

plt.boxplot(loss_direct, 
            positions=np.arange(num_boxes) - 0.1,
            widths=0.5, 
            patch_artist=True)
                  
plt.boxplot(loss_2step, 
            positions=np.arange(num_boxes) + 0.1,
            widths=0.5, 
            patch_artist=True)

                  
plt.boxplot(loss_3step, 
            positions=np.arange(num_boxes) + 0.1,
            widths=0.5, 
            patch_artist=True)


plt.xticks(np.arange(num_boxes))
plt.xlabel("Time Point")
plt.ylabel("MSE loss")

plt.title("Timing & Accuracy Comparison")
plt.tight_layout()
plt.show()
