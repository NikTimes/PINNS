# %%
import sys
sys.path.insert(0, "../..")

from src.models        import DeepONet, build_deeponet
from src.data          import ODEIterableDataset, LatinHypercubeSampler
from src.physics       import harm_osc
from src.training      import Trainer, build_dataloaders

import numpy as np
import matplotlib.pyplot as plt 
import torch
from torch.utils.data import DataLoader

device        = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Training

# %%
# Initialize Harmonic Oscillator Object 
k = 2.0
c = 0.1
system = harm_osc([k, c])

# Initialize Sampler Object 
sampler = LatinHypercubeSampler(

    dimensions=2,
    lows      = [-1.0, -1.0],
    highs     = [1.0, 1.0]
    
)

# %%
# Initialize Training and validation dataset

train_dataset    = ODEIterableDataset(size = 1000,
                                      system_class = system,
                                      sampler      = sampler,
                                      t_span       = (0, 10),
                                      output_mask  = np.array([0]))

val_dataset      = ODEIterableDataset(size = 10,
                                      system_class = system,
                                      sampler      = sampler,
                                      t_span       = (0, 10),
                                      output_mask  = np.array([0]))

# %%
# Set Up DeepONet configuration 

DEEPONET_CONFIG = {
    
    "hidden_size" : 32,
    "depth"       : 4,
    "latent_size" : 50,
    "input_size_b": 2,
    "input_size_t": 1,
    "output_size" : 1,
    "activation"  : "tanh",

}

# Initialize DeepONet network 

deeponet = build_deeponet(DEEPONET_CONFIG)

# %%
# Set Up training Configuration as well as optimizer and loss functions

TRAIN_CONFIG = {

    "num_epochs"     : 80,
    "learning_rate"  : 0.0068741,
    "batch_size"     : 32,
    "num_workers"    : 2,
    "Save_model"     : False,
    "Save_directory" : "../../weights/best_1d_osc.pth"
}

optimizer = torch.optim.Adam
loss_fn   = torch.nn.MSELoss()

# %%
# Initialize Train Object and Train 

trainer   = Trainer(
    model         = deeponet,
    train_dataset = train_dataset, 
    val_dataset   = val_dataset, 
    optimizer     = optimizer,
    loss_fn       = loss_fn, 
    train_cfg     = TRAIN_CONFIG,
    model_cfg     = DEEPONET_CONFIG
)

trainer.run()
# Out:
# Finishing previous runs because reinit is set to 'default'.
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>▁</td></tr><tr><td>val_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>-2.225</td></tr><tr><td>val_loss</td><td>-3.46009</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">woven-cosmos-25</strong> at: <a href='https://wandb.ai/nikpursals/PINNS-testing/runs/l9ujtagz' target="_blank">https://wandb.ai/nikpursals/PINNS-testing/runs/l9ujtagz</a><br> View project at: <a href='https://wandb.ai/nikpursals/PINNS-testing' target="_blank">https://wandb.ai/nikpursals/PINNS-testing</a><br>Synced 2 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260319_155115-l9ujtagz/logs</code>
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/home/enricp/repos/PINNS/notebooks/wandb/run-20260319_161738-nxkl0c48</code>
# Syncing run <strong><a href='https://wandb.ai/nikpursals/PINNS-testing/runs/nxkl0c48' target="_blank">fresh-wind-26</a></strong> to <a href='https://wandb.ai/nikpursals/PINNS-testing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nikpursals/PINNS-testing' target="_blank">https://wandb.ai/nikpursals/PINNS-testing</a>
#  View run at <a href='https://wandb.ai/nikpursals/PINNS-testing/runs/nxkl0c48' target="_blank">https://wandb.ai/nikpursals/PINNS-testing/runs/nxkl0c48</a>
# Training:  10%|█         | 8/80 [00:16<02:31,  2.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 13
#       1 # Initialize Train Object and Train
#       3 trainer   = Trainer(
#       4     model         = deeponet,
#       5     train_dataset = train_dataset,
#    (...)     10     model_cfg     = DEEPONET_CONFIG
#      11 )
# ---> 13 trainer.run()
#
# File ~/repos/PINNS/notebooks/../src/training/trainer.py:60, in Trainer.run(self, config)
#      57 train_loss = train_one_epoch(self.model, train_loader, self.optimizer, self.loss_fn, device)
#      59 # Validation Epoch
# ---> 60 val_loss   = validate(self.model, train_loader, self.loss_fn, device)
#      62 # Weights And Biases Log
#      63 wandb.log({"train_loss": np.log(train_loss), "val_loss": np.log(val_loss)})
#
# File ~/repos/PINNS/notebooks/../src/training/engine.py:42, in validate(model, loader, loss_fn, device)
#      39 total_loss  = 0.0
#      40 steps       = 0
# ---> 42 for batch in loader:
#      44     inputs  = [x.to(device) for x in batch[:-1]]  # all but last = inputs
#      45     targets = batch[-1].to(device)
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/utils/data/dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1492, in _MultiProcessingDataLoaderIter._next_data(self)
#    1489     return self._process_data(data, worker_id)
#    1491 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1492 idx, data = self._get_data()
#    1493 self._tasks_outstanding -= 1
#    1494 if self._dataset_kind == _DatasetKind.Iterable:
#    1495     # Check for _IterableDatasetStopIteration
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1454, in _MultiProcessingDataLoaderIter._get_data(self)
#    1450     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1451     # need to call `.task_done()` because we don't use `.join()`.
#    1452 else:
#    1453     while True:
# -> 1454         success, data = self._try_get_data()
#    1455         if success:
#    1456             return data
#
# File ~/miniconda3/envs/physics/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1285, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1272 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1273     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1274     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1282     # Returns a 2-tuple:
#    1283     #   (bool: whether successfully get data, any: data if successful else None)
#    1284     try:
# -> 1285         data = self._data_queue.get(timeout=timeout)
#    1286         return (True, data)
#    1287     except Exception as e:
#    1288         # At timeout and error, we manually check whether any worker has
#    1289         # failed. Note that this is the only mechanism for Windows to detect
#    1290         # worker failures.
#
# File ~/miniconda3/envs/physics/lib/python3.12/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/miniconda3/envs/physics/lib/python3.12/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/miniconda3/envs/physics/lib/python3.12/multiprocessing/connection.py:440, in Connection._poll(self, timeout)
#     439 def _poll(self, timeout):
# --> 440     r = wait([self], timeout)
#     441     return bool(r)
#
# File ~/miniconda3/envs/physics/lib/python3.12/multiprocessing/connection.py:1136, in wait(object_list, timeout)
#    1133     deadline = time.monotonic() + timeout
#    1135 while True:
# -> 1136     ready = selector.select(timeout)
#    1137     if ready:
#    1138         return [key.fileobj for (key, events) in ready]
#
# File ~/miniconda3/envs/physics/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
